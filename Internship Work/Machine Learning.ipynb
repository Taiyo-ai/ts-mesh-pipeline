# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WS_CREDIT_GAP_csv_col.csv')

# %%
display(df)
# Out:
#        Frequency Borrowers' country                Borrowing sector  \
# 0    Q:Quarterly       AR:Argentina  P:Private non-financial sector
# 1    Q:Quarterly       AR:Argentina  P:Private non-financial sector
# 2    Q:Quarterly       AR:Argentina  P:Private non-financial sector
# 3    Q:Quarterly         AT:Austria  P:Private non-financial sector
# 4    Q:Quarterly         AT:Austria  P:Private non-financial sector
# ..           ...                ...                             ...
# 127  Q:Quarterly       XM:Euro area  P:Private non-financial sector
# 128  Q:Quarterly       XM:Euro area  P:Private non-financial sector
# 129  Q:Quarterly    ZA:South Africa  P:Private non-financial sector
# 130  Q:Quarterly    ZA:South Africa  P:Private non-financial sector
# 131  Q:Quarterly    ZA:South Africa  P:Private non-financial sector
#
#     Lending sector                  Credit gap data type  \
# 0    A:All sectors  A:Credit-to-GDP ratios (actual data)
# ...

# %%
df_1 = pd.DataFrame()

# %%
df_1['country'] = df["Borrowers' country"]
df_1.head(3)
# Out:
#         country
# 0  AR:Argentina
# 1  AR:Argentina
# 2  AR:Argentina

# %%
def country_slash(row):
    row = row[3:]
    return row

# %%
df_1['country_1'] = df_1['country'].apply(country_slash)

# %%
df_1.head(5)
# Out:
#         country  country_1
# 0  AR:Argentina  Argentina
# 1  AR:Argentina  Argentina
# 2  AR:Argentina  Argentina
# 3    AT:Austria    Austria
# 4    AT:Austria    Austria

# %%
df_1.drop('country' , axis = 1, inplace =True)
df_1.head()
# Out:
#    country_1
# 0  Argentina
# 1  Argentina
# 2  Argentina
# 3    Austria
# 4    Austria

# %%
df['Time Period'].nunique()
# Out:
# 132

# %%
df_1['Time_Stamp'] = df['Time Period']

# %%
df_1.head(3)
# Out:
#    country_1  Time_Stamp
# 0  Argentina  Q:AR:P:A:A
# 1  Argentina  Q:AR:P:A:B
# 2  Argentina  Q:AR:P:A:C

# %%
df_1.to_csv('submission.csv' , index = False)
